# %% [markdown]
# # Importing libraries and dataset

# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.model_selection import train_test_split as tts
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
train = pd.read_csv('/kaggle/input/fake-news/train.csv')
train.sample(2)
# Out:
#           id                                              title  \
# 7895    7895         ‘We Are Orphans Here’ - The New York Times
# 12448  12448  North Dakota had 292 oil spills in 2 years off...
#
#                author                                               text  \
# 7895   Rachel Kushner  Standing at an intersection in Shuafat Refugee...
# 12448           Quest  We Are Change \nNorth Dakota had nearly 300 oi...
#
#        label
# 7895       0
# 12448      1

# %%
test = pd.read_csv('/kaggle/input/fake-news/test (3).csv')
test.sample(2)
# Out:
#          id                                              title  \
# 3541  24341  Anonymity: The Greatest Weapon Against Oppression
# 543   21343  Wikileaks’ Julian Assange at Embassy Balcony: ...
#
#               author                                               text
# 3541    ActivistPost  By Learn Liberty “Anonymity is a shield from t...
# 543   Oliver JJ Lane  Wikileaks founder Julian Assange appeared on t...

# %% [markdown]
# # Preprecessing

# %%
train.isnull().sum()
# Out:
# id           0
# title      558
# author    1957
# text        39
# label        0
# dtype: int64

# %%
train.dropna(inplace=True)
train.reset_index(inplace=True)

# %%
train.isnull().sum()
# Out:
# index     0
# id        0
# title     0
# author    0
# text      0
# label     0
# dtype: int64

# %%
train.shape
# Out:
# (18285, 6)

# %%
test.isnull().sum()
# Out:
# id          0
# title     122
# author    503
# text        7
# dtype: int64

# %%
test.shape
# Out:
# (5200, 4)

# %%
test.dropna(inplace=True)
test.reset_index(inplace=True)

# %%
test.isnull().sum()
# Out:
# index     0
# id        0
# title     0
# author    0
# text      0
# dtype: int64

# %%
test.shape
# Out:
# (4575, 5)

# %%
x = train.title+' '+train.author
x[:2]
# Out:
# 0    House Dem Aide: We Didn’t Even See Comey’s Let...
# 1    FLYNN: Hillary Clinton, Big Woman on Campus - ...
# dtype: object

# %%
y = train.label
y[:5]
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: label, dtype: int64

# %%
# applying stemming

# %%
ps = PorterStemmer()

# %%
corpus=[]
for i in range(len(x)):
    r = x[i]
    r = re.sub('[^a-zA-Z]',' ',r)
    r = r.lower()
    r = r.split()
    r = [ps.stem(w) for w in r if not w in stopwords.words('english')]
    r = ' '.join(r)
    corpus.append(r)

# %%
x = corpus

# %%
vect = TfidfVectorizer()

# %%
x = vect.fit_transform(x)

# %%
x.shape
# Out:
# (18285, 15960)

# %%
xtr, xte, ytr, yte = tts(x,y,test_size=0.2, random_state=0)

# %% [markdown]
# # Modeling

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
cls = MultinomialNB()
cls.fit(xtr, ytr)
# Out:
# MultinomialNB()

# %%
yp = cls.predict(xte)
print(accuracy_score(yte, yp))
# Out:
# 0.9540607054963085

# %%
from lightgbm import LGBMClassifier
params = {'learning_rate':.08, 'n_estimators':440}
model = LGBMClassifier(**params)
model.fit(xtr, ytr, eval_set=(xte, yte))
model.score(xte, yte)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# [1]	valid_0's binary_logloss: 0.616845
# [2]	valid_0's binary_logloss: 0.557317
# [3]	valid_0's binary_logloss: 0.506205
# [4]	valid_0's binary_logloss: 0.462063
# [5]	valid_0's binary_logloss: 0.423452
# [6]	valid_0's binary_logloss: 0.389592
# [7]	valid_0's binary_logloss: 0.359329
# [8]	valid_0's binary_logloss: 0.33289
# [9]	valid_0's binary_logloss: 0.309068
# [10]	valid_0's binary_logloss: 0.287834
# [11]	valid_0's binary_logloss: 0.268792
# [12]	valid_0's binary_logloss: 0.251587
# [13]	valid_0's binary_logloss: 0.236106
# [14]	valid_0's binary_logloss: 0.222126
# [15]	valid_0's binary_logloss: 0.209636
# [16]	valid_0's binary_logloss: 0.197855
# [17]	valid_0's binary_logloss: 0.187009
# [18]	valid_0's binary_logloss: 0.177592
# [19]	valid_0's binary_logloss: 0.168397
# [20]	valid_0's binary_logloss: 0.160101
# [21]	valid_0's binary_logloss: 0.152623
# [22]	valid_0's binary_logloss: 0.145679
# [23]	valid_0's binary_logloss: 0.139349
# [24]	valid_0's binary_logloss: 0.133576
# [25]	valid_0's binary_logloss: 0.12839
# [26]	valid_0's binary_logloss: 0.123314
# [27]	valid_0's binary_logloss: 0.118876
# [28]	valid_0's binary_logloss: 0.114913
# [29]	valid_0's binary_logloss: 0.111255
# [30]	valid_0's binary_logloss: 0.108237
# [31]	valid_0's binary_logloss: 0.104121
# [32]	valid_0's binary_logloss: 0.10083
# [33]	valid_0's binary_logloss: 0.0979995
# [34]	valid_0's binary_logloss: 0.0953063
# [35]	valid_0's binary_logloss: 0.0931309
# [36]	valid_0's binary_logloss: 0.0906806
# [37]	valid_0's binary_logloss: 0.0880897
# [38]	valid_0's binary_logloss: 0.0859714
# [39]	valid_0's binary_logloss: 0.0840557
# [40]	valid_0's binary_logloss: 0.0824825
# [41]	valid_0's binary_logloss: 0.0808075
# [42]	valid_0's binary_logloss: 0.0788052
# [43]	valid_0's binary_logloss: 0.0767238
# [44]	valid_0's binary_logloss: 0.0751677
# [45]	valid_0's binary_logloss: 0.0736869
# [46]	valid_0's binary_logloss: 0.0717379
# [47]	valid_0's binary_logloss: 0.0705268
# [48]	valid_0's binary_logloss: 0.0693494
# [49]	valid_0's binary_logloss: 0.0681292
# [50]	valid_0's binary_logloss: 0.0669972
# [51]	valid_0's binary_logloss: 0.0658865
# [52]	valid_0's binary_logloss: 0.0649314
# [53]	valid_0's binary_logloss: 0.0642424
# [54]	valid_0's binary_logloss: 0.063563
# [55]	valid_0's binary_logloss: 0.0628896
# [56]	valid_0's binary_logloss: 0.0624206
# [57]	valid_0's binary_logloss: 0.0616514
# [58]	valid_0's binary_logloss: 0.060932
# [59]	valid_0's binary_logloss: 0.0603678
# [60]	valid_0's binary_logloss: 0.0596215
# [61]	valid_0's binary_logloss: 0.0592203
# [62]	valid_0's binary_logloss: 0.0586623
# [63]	valid_0's binary_logloss: 0.058334
# [64]	valid_0's binary_logloss: 0.058076
# [65]	valid_0's binary_logloss: 0.0575588
# [66]	valid_0's binary_logloss: 0.0568661
# [67]	valid_0's binary_logloss: 0.0564933
# [68]	valid_0's binary_logloss: 0.0561233
# [69]	valid_0's binary_logloss: 0.0556309
# [70]	valid_0's binary_logloss: 0.0553302
# [71]	valid_0's binary_logloss: 0.0548719
# [72]	valid_0's binary_logloss: 0.0547113
# [73]	valid_0's binary_logloss: 0.0545093
# [74]	valid_0's binary_logloss: 0.0542243
# [75]	valid_0's binary_logloss: 0.053871
# [76]	valid_0's binary_logloss: 0.0534923
# [77]	valid_0's binary_logloss: 0.053111
# [78]	valid_0's binary_logloss: 0.0529068
# [79]	valid_0's binary_logloss: 0.0524437
# [80]	valid_0's binary_logloss: 0.0520168
# [81]	valid_0's binary_logloss: 0.0515821
# [82]	valid_0's binary_logloss: 0.0512188
# [83]	valid_0's binary_logloss: 0.0510869
# [84]	valid_0's binary_logloss: 0.0507285
# [85]	valid_0's binary_logloss: 0.0503624
# [86]	valid_0's binary_logloss: 0.0501958
# [87]	valid_0's binary_logloss: 0.0498984
# [88]	valid_0's binary_logloss: 0.0494421
# [89]	valid_0's binary_logloss: 0.0491449
# [90]	valid_0's binary_logloss: 0.0489426
# [91]	valid_0's binary_logloss: 0.048701
# [92]	valid_0's binary_logloss: 0.0484912
# [93]	valid_0's binary_logloss: 0.0481235
# [94]	valid_0's binary_logloss: 0.0477904
# [95]	valid_0's binary_logloss: 0.0475546
# [96]	valid_0's binary_logloss: 0.0473284
# [97]	valid_0's binary_logloss: 0.0471894
# [98]	valid_0's binary_logloss: 0.0469309
# [99]	valid_0's binary_logloss: 0.046621
# [100]	valid_0's binary_logloss: 0.0464997
# [101]	valid_0's binary_logloss: 0.0461554
# [102]	valid_0's binary_logloss: 0.0460121
# [103]	valid_0's binary_logloss: 0.0458793
# [104]	valid_0's binary_logloss: 0.0458177
# [105]	valid_0's binary_logloss: 0.0457003
# [106]	valid_0's binary_logloss: 0.0453585
# [107]	valid_0's binary_logloss: 0.0452584
# [108]	valid_0's binary_logloss: 0.0450945
# [109]	valid_0's binary_logloss: 0.0450042
# [110]	valid_0's binary_logloss: 0.0447123
# [111]	valid_0's binary_logloss: 0.0445865
# [112]	valid_0's binary_logloss: 0.0444365
# [113]	valid_0's binary_logloss: 0.0443182
# [114]	valid_0's binary_logloss: 0.0440911
# [115]	valid_0's binary_logloss: 0.0439018
# [116]	valid_0's binary_logloss: 0.043706
# [117]	valid_0's binary_logloss: 0.0436208
# [118]	valid_0's binary_logloss: 0.0435367
# [119]	valid_0's binary_logloss: 0.0435397
# [120]	valid_0's binary_logloss: 0.0434067
# [121]	valid_0's binary_logloss: 0.0433617
# [122]	valid_0's binary_logloss: 0.0433844
# [123]	valid_0's binary_logloss: 0.0433109
# [124]	valid_0's binary_logloss: 0.0431155
# [125]	valid_0's binary_logloss: 0.0430461
# [126]	valid_0's binary_logloss: 0.0428673
# [127]	valid_0's binary_logloss: 0.0426468
# [128]	valid_0's binary_logloss: 0.0424699
# [129]	valid_0's binary_logloss: 0.0423522
# [130]	valid_0's binary_logloss: 0.0423206
# [131]	valid_0's binary_logloss: 0.042152
# [132]	valid_0's binary_logloss: 0.0421023
# [133]	valid_0's binary_logloss: 0.0419786
# [134]	valid_0's binary_logloss: 0.0418953
# [135]	valid_0's binary_logloss: 0.0417528
# [136]	valid_0's binary_logloss: 0.0416234
# [137]	valid_0's binary_logloss: 0.041591
# [138]	valid_0's binary_logloss: 0.0415596
# [139]	valid_0's binary_logloss: 0.0414468
# [140]	valid_0's binary_logloss: 0.0413763
# [141]	valid_0's binary_logloss: 0.0412802
# [142]	valid_0's binary_logloss: 0.041132
# [143]	valid_0's binary_logloss: 0.0409638
# [144]	valid_0's binary_logloss: 0.040936
# [145]	valid_0's binary_logloss: 0.0409243
# [146]	valid_0's binary_logloss: 0.0409571
# [147]	valid_0's binary_logloss: 0.0408943
# [148]	valid_0's binary_logloss: 0.0408885
# [149]	valid_0's binary_logloss: 0.0407205
# [150]	valid_0's binary_logloss: 0.0406505
# [151]	valid_0's binary_logloss: 0.0406398
# [152]	valid_0's binary_logloss: 0.0406853
# [153]	valid_0's binary_logloss: 0.0405738
# [154]	valid_0's binary_logloss: 0.0405851
# [155]	valid_0's binary_logloss: 0.0404425
# [156]	valid_0's binary_logloss: 0.0403488
# [157]	valid_0's binary_logloss: 0.0403804
# [158]	valid_0's binary_logloss: 0.0403435
# [159]	valid_0's binary_logloss: 0.0403463
# [160]	valid_0's binary_logloss: 0.0403162
# [161]	valid_0's binary_logloss: 0.0402678
# [162]	valid_0's binary_logloss: 0.0401696
# [163]	valid_0's binary_logloss: 0.0400681
# [164]	valid_0's binary_logloss: 0.0399399
# [165]	valid_0's binary_logloss: 0.0398061
# [166]	valid_0's binary_logloss: 0.039753
# [167]	valid_0's binary_logloss: 0.0397294
# [168]	valid_0's binary_logloss: 0.0398807
# [169]	valid_0's binary_logloss: 0.0398568
# [170]	valid_0's binary_logloss: 0.0397656
# [171]	valid_0's binary_logloss: 0.0397205
# [172]	valid_0's binary_logloss: 0.0396347
# [173]	valid_0's binary_logloss: 0.0395316
# [174]	valid_0's binary_logloss: 0.0394813
# [175]	valid_0's binary_logloss: 0.0395099
# [176]	valid_0's binary_logloss: 0.0394743
# [177]	valid_0's binary_logloss: 0.0394551
# [178]	valid_0's binary_logloss: 0.0393384
# [179]	valid_0's binary_logloss: 0.0393847
# [180]	valid_0's binary_logloss: 0.0394252
# [181]	valid_0's binary_logloss: 0.0393991
# [182]	valid_0's binary_logloss: 0.0393586
# [183]	valid_0's binary_logloss: 0.03934
# [184]	valid_0's binary_logloss: 0.0392944
# [185]	valid_0's binary_logloss: 0.0393392
# [186]	valid_0's binary_logloss: 0.0392555
# [187]	valid_0's binary_logloss: 0.0392779
# [188]	valid_0's binary_logloss: 0.0392417
# [189]	valid_0's binary_logloss: 0.0391362
# [190]	valid_0's binary_logloss: 0.0391895
# [191]	valid_0's binary_logloss: 0.0391459
# [192]	valid_0's binary_logloss: 0.0391544
# [193]	valid_0's binary_logloss: 0.0391612
# [194]	valid_0's binary_logloss: 0.0391661
# [195]	valid_0's binary_logloss: 0.0391979
# [196]	valid_0's binary_logloss: 0.0392212
# [197]	valid_0's binary_logloss: 0.0392646
# [198]	valid_0's binary_logloss: 0.0392463
# [199]	valid_0's binary_logloss: 0.039186
# [200]	valid_0's binary_logloss: 0.0390985
# [201]	valid_0's binary_logloss: 0.0390439
# [202]	valid_0's binary_logloss: 0.0390712
# [203]	valid_0's binary_logloss: 0.0390651
# [204]	valid_0's binary_logloss: 0.0389773
# [205]	valid_0's binary_logloss: 0.0389544
# [206]	valid_0's binary_logloss: 0.0389886
# [207]	valid_0's binary_logloss: 0.0390168
# [208]	valid_0's binary_logloss: 0.039045
# [209]	valid_0's binary_logloss: 0.0390381
# [210]	valid_0's binary_logloss: 0.0389793
# [211]	valid_0's binary_logloss: 0.0388928
# [212]	valid_0's binary_logloss: 0.0388968
# [213]	valid_0's binary_logloss: 0.0388754
# [214]	valid_0's binary_logloss: 0.0388346
# [215]	valid_0's binary_logloss: 0.0388827
# [216]	valid_0's binary_logloss: 0.0389098
# [217]	valid_0's binary_logloss: 0.03894
# [218]	valid_0's binary_logloss: 0.0389681
# [219]	valid_0's binary_logloss: 0.0389701
# [220]	valid_0's binary_logloss: 0.0389197
# [221]	valid_0's binary_logloss: 0.038953
# [222]	valid_0's binary_logloss: 0.0389329
# [223]	valid_0's binary_logloss: 0.0389678
# [224]	valid_0's binary_logloss: 0.0389121
# [225]	valid_0's binary_logloss: 0.0389414
# [226]	valid_0's binary_logloss: 0.0388979
# [227]	valid_0's binary_logloss: 0.0388802
# [228]	valid_0's binary_logloss: 0.0388387
# [229]	valid_0's binary_logloss: 0.038942
# [230]	valid_0's binary_logloss: 0.0389285
# [231]	valid_0's binary_logloss: 0.038905
# [232]	valid_0's binary_logloss: 0.0389491
# [233]	valid_0's binary_logloss: 0.03891
# [234]	valid_0's binary_logloss: 0.0389336
# [235]	valid_0's binary_logloss: 0.0389722
# [236]	valid_0's binary_logloss: 0.0389546
# [237]	valid_0's binary_logloss: 0.0389107
# [238]	valid_0's binary_logloss: 0.0390099
# [239]	valid_0's binary_logloss: 0.0389603
# [240]	valid_0's binary_logloss: 0.0390238
# [241]	valid_0's binary_logloss: 0.0390573
# [242]	valid_0's binary_logloss: 0.0390354
# [243]	valid_0's binary_logloss: 0.0391215
# [244]	valid_0's binary_logloss: 0.0390824
# [245]	valid_0's binary_logloss: 0.0390568
# [246]	valid_0's binary_logloss: 0.0390445
# [247]	valid_0's binary_logloss: 0.0391738
# [248]	valid_0's binary_logloss: 0.0391785
# [249]	valid_0's binary_logloss: 0.0391368
# [250]	valid_0's binary_logloss: 0.0391152
# [251]	valid_0's binary_logloss: 0.0391804
# [252]	valid_0's binary_logloss: 0.0392775
# [253]	valid_0's binary_logloss: 0.0392806
# [254]	valid_0's binary_logloss: 0.039293
# [255]	valid_0's binary_logloss: 0.0392545
# [256]	valid_0's binary_logloss: 0.0393292
# [257]	valid_0's binary_logloss: 0.0392781
# [258]	valid_0's binary_logloss: 0.0393483
# [259]	valid_0's binary_logloss: 0.0393579
# [260]	valid_0's binary_logloss: 0.0393874
# [261]	valid_0's binary_logloss: 0.0393638
# [262]	valid_0's binary_logloss: 0.0394224
# [263]	valid_0's binary_logloss: 0.0394827
# [264]	valid_0's binary_logloss: 0.0394526
# [265]	valid_0's binary_logloss: 0.0394915
# [266]	valid_0's binary_logloss: 0.0395597
# [267]	valid_0's binary_logloss: 0.0395502
# [268]	valid_0's binary_logloss: 0.0395377
# [269]	valid_0's binary_logloss: 0.0395659
# [270]	valid_0's binary_logloss: 0.0395666
# [271]	valid_0's binary_logloss: 0.0396322
# [272]	valid_0's binary_logloss: 0.0395956
# [273]	valid_0's binary_logloss: 0.0395623
# [274]	valid_0's binary_logloss: 0.0395892
# [275]	valid_0's binary_logloss: 0.0396026
# [276]	valid_0's binary_logloss: 0.0396565
# [277]	valid_0's binary_logloss: 0.0396315
# [278]	valid_0's binary_logloss: 0.039693
# [279]	valid_0's binary_logloss: 0.0397265
# [280]	valid_0's binary_logloss: 0.0397292
# [281]	valid_0's binary_logloss: 0.0397135
# [282]	valid_0's binary_logloss: 0.0397261
# [283]	valid_0's binary_logloss: 0.0397105
# [284]	valid_0's binary_logloss: 0.0397596
# [285]	valid_0's binary_logloss: 0.0397606
# [286]	valid_0's binary_logloss: 0.0398551
# [287]	valid_0's binary_logloss: 0.0399676
# [288]	valid_0's binary_logloss: 0.0399776
# [289]	valid_0's binary_logloss: 0.039897
# [290]	valid_0's binary_logloss: 0.0399178
# [291]	valid_0's binary_logloss: 0.0398937
# [292]	valid_0's binary_logloss: 0.0398497
# [293]	valid_0's binary_logloss: 0.0399091
# [294]	valid_0's binary_logloss: 0.0398686
# [295]	valid_0's binary_logloss: 0.039904
# [296]	valid_0's binary_logloss: 0.0399565
# [297]	valid_0's binary_logloss: 0.0399619
# [298]	valid_0's binary_logloss: 0.0399825
# [299]	valid_0's binary_logloss: 0.0400141
# [300]	valid_0's binary_logloss: 0.040059
# [301]	valid_0's binary_logloss: 0.0399594
# [302]	valid_0's binary_logloss: 0.0400638
# [303]	valid_0's binary_logloss: 0.0400782
# [304]	valid_0's binary_logloss: 0.0400689
# [305]	valid_0's binary_logloss: 0.0400886
# [306]	valid_0's binary_logloss: 0.040074
# [307]	valid_0's binary_logloss: 0.0400861
# [308]	valid_0's binary_logloss: 0.0400933
# [309]	valid_0's binary_logloss: 0.0401793
# [310]	valid_0's binary_logloss: 0.0401931
# [311]	valid_0's binary_logloss: 0.040282
# [312]	valid_0's binary_logloss: 0.0403644
# [313]	valid_0's binary_logloss: 0.04037
# [314]	valid_0's binary_logloss: 0.0404674
# [315]	valid_0's binary_logloss: 0.0404937
# [316]	valid_0's binary_logloss: 0.0405213
# [317]	valid_0's binary_logloss: 0.0405945
# [318]	valid_0's binary_logloss: 0.0405834
# [319]	valid_0's binary_logloss: 0.0405443
# [320]	valid_0's binary_logloss: 0.0406951
# [321]	valid_0's binary_logloss: 0.0407743
# [322]	valid_0's binary_logloss: 0.0407398
# [323]	valid_0's binary_logloss: 0.0408031
# [324]	valid_0's binary_logloss: 0.0408813
# [325]	valid_0's binary_logloss: 0.0408698
# [326]	valid_0's binary_logloss: 0.0409339
# [327]	valid_0's binary_logloss: 0.0409916
# [328]	valid_0's binary_logloss: 0.0409546
# [329]	valid_0's binary_logloss: 0.0410753
# [330]	valid_0's binary_logloss: 0.0410738
# [331]	valid_0's binary_logloss: 0.0409845
# [332]	valid_0's binary_logloss: 0.0410021
# [333]	valid_0's binary_logloss: 0.0410612
# [334]	valid_0's binary_logloss: 0.0410772
# [335]	valid_0's binary_logloss: 0.04116
# [336]	valid_0's binary_logloss: 0.041149
# [337]	valid_0's binary_logloss: 0.0412141
# [338]	valid_0's binary_logloss: 0.0412795
# [339]	valid_0's binary_logloss: 0.041326
# [340]	valid_0's binary_logloss: 0.0413593
# [341]	valid_0's binary_logloss: 0.0413787
# [342]	valid_0's binary_logloss: 0.0413809
# [343]	valid_0's binary_logloss: 0.0413893
# [344]	valid_0's binary_logloss: 0.0414336
# [345]	valid_0's binary_logloss: 0.0414399
# [346]	valid_0's binary_logloss: 0.0415058
# [347]	valid_0's binary_logloss: 0.0415248
# [348]	valid_0's binary_logloss: 0.0415978
# [349]	valid_0's binary_logloss: 0.0416305
# [350]	valid_0's binary_logloss: 0.0417351
# [351]	valid_0's binary_logloss: 0.0417148
# [352]	valid_0's binary_logloss: 0.0418347
# [353]	valid_0's binary_logloss: 0.0419357
# [354]	valid_0's binary_logloss: 0.0419845
# [355]	valid_0's binary_logloss: 0.0419673
# [356]	valid_0's binary_logloss: 0.0419312
# [357]	valid_0's binary_logloss: 0.0419298
# [358]	valid_0's binary_logloss: 0.0419351
# [359]	valid_0's binary_logloss: 0.0419758
# [360]	valid_0's binary_logloss: 0.0420115
# [361]	valid_0's binary_logloss: 0.0420801
# [362]	valid_0's binary_logloss: 0.042142
# [363]	valid_0's binary_logloss: 0.0421255
# [364]	valid_0's binary_logloss: 0.0421485
# [365]	valid_0's binary_logloss: 0.0421362
# [366]	valid_0's binary_logloss: 0.0421747
# [367]	valid_0's binary_logloss: 0.0421909
# [368]	valid_0's binary_logloss: 0.0422589
# [369]	valid_0's binary_logloss: 0.0423357
# [370]	valid_0's binary_logloss: 0.0423047
# [371]	valid_0's binary_logloss: 0.0423635
# [372]	valid_0's binary_logloss: 0.0423775
# [373]	valid_0's binary_logloss: 0.0424057
# [374]	valid_0's binary_logloss: 0.0424483
# [375]	valid_0's binary_logloss: 0.0425108
# [376]	valid_0's binary_logloss: 0.0425265
# [377]	valid_0's binary_logloss: 0.0425419
# [378]	valid_0's binary_logloss: 0.0425943
# [379]	valid_0's binary_logloss: 0.0427152
# [380]	valid_0's binary_logloss: 0.0427351
# [381]	valid_0's binary_logloss: 0.0428636
# [382]	valid_0's binary_logloss: 0.0428865
# [383]	valid_0's binary_logloss: 0.0428466
# [384]	valid_0's binary_logloss: 0.0429264
# [385]	valid_0's binary_logloss: 0.0429961
# [386]	valid_0's binary_logloss: 0.0431473
# [387]	valid_0's binary_logloss: 0.0432055
# [388]	valid_0's binary_logloss: 0.0432034
# [389]	valid_0's binary_logloss: 0.0433036
# [390]	valid_0's binary_logloss: 0.0432887
# [391]	valid_0's binary_logloss: 0.0432903
# [392]	valid_0's binary_logloss: 0.043305
# [393]	valid_0's binary_logloss: 0.043419
# [394]	valid_0's binary_logloss: 0.0434974
# [395]	valid_0's binary_logloss: 0.0435609
# [396]	valid_0's binary_logloss: 0.0435272
# [397]	valid_0's binary_logloss: 0.0435622
# [398]	valid_0's binary_logloss: 0.0436283
# [399]	valid_0's binary_logloss: 0.043673
# [400]	valid_0's binary_logloss: 0.0436623
# [401]	valid_0's binary_logloss: 0.0437213
# [402]	valid_0's binary_logloss: 0.0437228
# [403]	valid_0's binary_logloss: 0.043752
# [404]	valid_0's binary_logloss: 0.043751
# [405]	valid_0's binary_logloss: 0.0438303
# [406]	valid_0's binary_logloss: 0.0438935
# [407]	valid_0's binary_logloss: 0.0438723
# [408]	valid_0's binary_logloss: 0.0439231
# [409]	valid_0's binary_logloss: 0.0439962
# [410]	valid_0's binary_logloss: 0.0440468
# [411]	valid_0's binary_logloss: 0.0440647
# [412]	valid_0's binary_logloss: 0.0440894
# [413]	valid_0's binary_logloss: 0.0440963
# [414]	valid_0's binary_logloss: 0.0441754
# [415]	valid_0's binary_logloss: 0.0442506
# [416]	valid_0's binary_logloss: 0.0442482
# [417]	valid_0's binary_logloss: 0.0442308
# [418]	valid_0's binary_logloss: 0.0443257
# [419]	valid_0's binary_logloss: 0.0442895
# [420]	valid_0's binary_logloss: 0.0443289
# [421]	valid_0's binary_logloss: 0.0443198
# [422]	valid_0's binary_logloss: 0.0443783
# [423]	valid_0's binary_logloss: 0.0444741
# [424]	valid_0's binary_logloss: 0.0445018
# [425]	valid_0's binary_logloss: 0.0446671
# [426]	valid_0's binary_logloss: 0.0447191
# [427]	valid_0's binary_logloss: 0.0446973
# [428]	valid_0's binary_logloss: 0.0447221
# [429]	valid_0's binary_logloss: 0.0448033
# [430]	valid_0's binary_logloss: 0.0448514
# [431]	valid_0's binary_logloss: 0.0448884
# [432]	valid_0's binary_logloss: 0.0449936
# [433]	valid_0's binary_logloss: 0.0451047
# [434]	valid_0's binary_logloss: 0.0451344
# [435]	valid_0's binary_logloss: 0.0451141
# [436]	valid_0's binary_logloss: 0.0452161
# [437]	valid_0's binary_logloss: 0.0452505
# [438]	valid_0's binary_logloss: 0.04528
# [439]	valid_0's binary_logloss: 0.0453263
# [440]	valid_0's binary_logloss: 0.0453738
# 0.9890620727372162

# %%
yp_ = model.predict(xte)
print(accuracy_score(yte, yp_))
# Out:
# 0.9890620727372162
